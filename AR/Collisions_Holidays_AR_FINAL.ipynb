# %%
# %matplotlib notebook

# %%
#import dependencies 
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import datetime
import datetime as dt
import time

#create file path
filename = "../Resources/NoHo_Street_Traffic_Collision_Data_2015_2019_v2.csv"
traffic_df = pd.read_csv(filename, sep=",", parse_dates=['Date Reported', 'Date Occurred', 'Time Occurred'], \
                         infer_datetime_format=['Date Reported', 'Date Occurred','Time Occurred'], low_memory=False)
traffic_df['Time Occurred'] = traffic_df['Time Occurred'].astype(str).astype(float)
traffic_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13072 entries, 0 to 13071
# Data columns (total 9 columns):
# DR Number             13072 non-null int64
# Date Reported         13072 non-null datetime64[ns]
# Date Occurred         13072 non-null datetime64[ns]
# Time Occurred         13072 non-null float64
# Reporting District    13072 non-null int64
# Address               13072 non-null object
# Cross Street          12752 non-null object
# Location              13072 non-null object
# MO Codes              12896 non-null object
# dtypes: datetime64[ns](2), float64(1), int64(2), object(4)
# memory usage: 919.2+ KB

# %%
traffic_df2 = traffic_df.drop(['Date Reported','Address','Cross Street','Location','MO Codes'],axis =1)
traffic_df2.head()
# Out:
#    DR Number Date Occurred  Time Occurred  Reporting District
# 0  151511105    2015-05-08            1.0                1599
# 1  161504186    2016-01-04            1.0                1599
# 2  181508642    2018-03-20            1.0                1599
# 3  151516620    2015-08-08            1.0                1588
# 4  171520919    2017-10-22            1.0                1599

# %%
##NEW YEAR'S DAY
nyd15 = traffic_df2[(traffic_df2["Date Occurred"] == '2015-01-01')]['DR Number'].count()
nyd16 = traffic_df2[(traffic_df2["Date Occurred"] == '2016-01-01')]['DR Number'].count()
nyd17 = traffic_df2[(traffic_df2["Date Occurred"] == '2017-01-01')]['DR Number'].count()
nyd18 = traffic_df2[(traffic_df2["Date Occurred"] == '2018-01-02')]['DR Number'].count()
nyd19 = traffic_df2[(traffic_df2["Date Occurred"] == '2019-01-01')]['DR Number'].count()
nyd = [nyd15,nyd16,nyd17,nyd18,nyd19]

##MLK DAY
mlk15 = traffic_df2[(traffic_df2["Date Occurred"] == '2015-01-19')]['DR Number'].count()
mlk16 = traffic_df2[(traffic_df2["Date Occurred"] == '2016-01-18')]['DR Number'].count()
mlk17 = traffic_df2[(traffic_df2["Date Occurred"] == '2017-01-16')]['DR Number'].count()
mlk18 = traffic_df2[(traffic_df2["Date Occurred"] == '2018-01-15')]['DR Number'].count()
mlk19 = traffic_df2[(traffic_df2["Date Occurred"] == '2019-01-21')]['DR Number'].count()
mlk = [mlk15,mlk16,mlk17,mlk18,mlk19]

##PRESIDENT'S DAY
pzd15 = traffic_df2[(traffic_df2["Date Occurred"] == '2015-02-16')]['DR Number'].count()
pzd16 = traffic_df2[(traffic_df2["Date Occurred"] == '2016-02-15')]['DR Number'].count()
pzd17 = traffic_df2[(traffic_df2["Date Occurred"] == '2017-02-20')]['DR Number'].count()
pzd18 = traffic_df2[(traffic_df2["Date Occurred"] == '2018-02-19')]['DR Number'].count()
pzd19 = traffic_df2[(traffic_df2["Date Occurred"] == '2019-02-18')]['DR Number'].count()
pzd = [pzd15,pzd16,pzd17,pzd18,pzd19]

##ST PATRICK'S DAY
spd15 = traffic_df2[(traffic_df2["Date Occurred"] == '2015-03-17')]['DR Number'].count()
spd16 = traffic_df2[(traffic_df2["Date Occurred"] == '2016-03-17')]['DR Number'].count()
spd17 = traffic_df2[(traffic_df2["Date Occurred"] == '2017-03-17')]['DR Number'].count()
spd18 = traffic_df2[(traffic_df2["Date Occurred"] == '2018-03-17')]['DR Number'].count()
spd19 = traffic_df2[(traffic_df2["Date Occurred"] == '2019-03-17')]['DR Number'].count()
spd = [spd15,spd16,spd17,spd18,spd19]

##CINCO DE MAYO
cdm15 = traffic_df2[(traffic_df2["Date Occurred"] == '2015-05-05')]['DR Number'].count()
cdm16 = traffic_df2[(traffic_df2["Date Occurred"] == '2016-05-05')]['DR Number'].count()
cdm17 = traffic_df2[(traffic_df2["Date Occurred"] == '2017-05-05')]['DR Number'].count()
cdm18 = traffic_df2[(traffic_df2["Date Occurred"] == '2018-05-05')]['DR Number'].count()
cdm19 = traffic_df2[(traffic_df2["Date Occurred"] == '2019-05-05')]['DR Number'].count()
cdm = [cdm15,cdm16,cdm17,cdm18,cdm19]

##MEMORIAL DAY
mrd15 = traffic_df2[(traffic_df2["Date Occurred"] == '2015-05-25')]['DR Number'].count()
mrd16 = traffic_df2[(traffic_df2["Date Occurred"] == '2016-05-30')]['DR Number'].count()
mrd17 = traffic_df2[(traffic_df2["Date Occurred"] == '2017-05-09')]['DR Number'].count()
mrd18 = traffic_df2[(traffic_df2["Date Occurred"] == '2018-05-28')]['DR Number'].count()
mrd19 = traffic_df2[(traffic_df2["Date Occurred"] == '2019-05-27')]['DR Number'].count()
mrd = [mrd15,mrd16,mrd17,mrd18,mrd19]

##INDEPENDENCE DAY
ind15 = traffic_df2[(traffic_df2["Date Occurred"] == '2015-07-03')]['DR Number'].count()
ind16 = traffic_df2[(traffic_df2["Date Occurred"] == '2016-07-04')]['DR Number'].count()
ind17 = traffic_df2[(traffic_df2["Date Occurred"] == '2017-07-04')]['DR Number'].count()
ind18 = traffic_df2[(traffic_df2["Date Occurred"] == '2018-07-04')]['DR Number'].count()
ind19 = traffic_df2[(traffic_df2["Date Occurred"] == '2019-07-04')]['DR Number'].count()
ind = [ind15,ind16,ind17,ind18,ind19]

##LABOR DAY
lbd15 = traffic_df2[(traffic_df2["Date Occurred"] == '2015-09-07')]['DR Number'].count()
lbd16 = traffic_df2[(traffic_df2["Date Occurred"] == '2016-09-05')]['DR Number'].count()
lbd17 = traffic_df2[(traffic_df2["Date Occurred"] == '2017-09-04')]['DR Number'].count()
lbd18 = traffic_df2[(traffic_df2["Date Occurred"] == '2018-09-03')]['DR Number'].count()
lbd19 = traffic_df2[(traffic_df2["Date Occurred"] == '2019-09-02')]['DR Number'].count()
lbd = [lbd15,lbd16,lbd17,lbd18,lbd19]

##COLUMBUS DAY
cld15 = traffic_df2[(traffic_df2["Date Occurred"] == '2015-10-12')]['DR Number'].count()
cld16 = traffic_df2[(traffic_df2["Date Occurred"] == '2016-10-10')]['DR Number'].count()
cld17 = traffic_df2[(traffic_df2["Date Occurred"] == '2017-10-09')]['DR Number'].count()
cld18 = traffic_df2[(traffic_df2["Date Occurred"] == '2018-10-08')]['DR Number'].count()
cld19 = traffic_df2[(traffic_df2["Date Occurred"] == '2019-10-14')]['DR Number'].count()
cld = [cld15,cld16,cld17,cld18,cld19]

##VETERANS DAY
vtd15 = traffic_df2[(traffic_df2["Date Occurred"] == '2015-11-11')]['DR Number'].count()
vtd16 = traffic_df2[(traffic_df2["Date Occurred"] == '2016-11-11')]['DR Number'].count()
vtd17 = traffic_df2[(traffic_df2["Date Occurred"] == '2017-11-11')]['DR Number'].count()
vtd18 = traffic_df2[(traffic_df2["Date Occurred"] == '2018-11-12')]['DR Number'].count()
vtd19 = traffic_df2[(traffic_df2["Date Occurred"] == '2019-11-11')]['DR Number'].count()
vtd = [vtd15,vtd16,vtd17,vtd18,vtd19]

##DAY AFTER THANKSGIVING DAY
btd15 = traffic_df2[(traffic_df2["Date Occurred"] == '2015-11-25')]['DR Number'].count()
btd16 = traffic_df2[(traffic_df2["Date Occurred"] == '2016-11-23')]['DR Number'].count()
btd17 = traffic_df2[(traffic_df2["Date Occurred"] == '2017-11-22')]['DR Number'].count()
btd18 = traffic_df2[(traffic_df2["Date Occurred"] == '2018-11-21')]['DR Number'].count()
btd19 = traffic_df2[(traffic_df2["Date Occurred"] == '2019-11-27')]['DR Number'].count()
btd = [btd15,btd16,btd17,btd18,btd19]

##THANKSGIVING DAY
tgd15 = traffic_df2[(traffic_df2["Date Occurred"] == '2015-11-26')]['DR Number'].count()
tgd16 = traffic_df2[(traffic_df2["Date Occurred"] == '2016-11-24')]['DR Number'].count()
tgd17 = traffic_df2[(traffic_df2["Date Occurred"] == '2017-11-23')]['DR Number'].count()
tgd18 = traffic_df2[(traffic_df2["Date Occurred"] == '2018-11-22')]['DR Number'].count()
tgd19 = traffic_df2[(traffic_df2["Date Occurred"] == '2019-11-28')]['DR Number'].count()
tgd = [tgd15,tgd16,tgd17,tgd18,tgd19]

##DAY AFTER THANKSGIVING DAY
atd15 = traffic_df2[(traffic_df2["Date Occurred"] == '2015-11-27')]['DR Number'].count()
atd16 = traffic_df2[(traffic_df2["Date Occurred"] == '2016-11-25')]['DR Number'].count()
atd17 = traffic_df2[(traffic_df2["Date Occurred"] == '2017-11-24')]['DR Number'].count()
atd18 = traffic_df2[(traffic_df2["Date Occurred"] == '2018-11-23')]['DR Number'].count()
atd19 = traffic_df2[(traffic_df2["Date Occurred"] == '2019-11-29')]['DR Number'].count()
atd = [atd15,atd16,atd17,atd18,atd19]

##CHRISTMAS EVE
ced15 = traffic_df2[(traffic_df2["Date Occurred"] == '2015-12-24')]['DR Number'].count()
ced16 = traffic_df2[(traffic_df2["Date Occurred"] == '2016-12-24')]['DR Number'].count()
ced17 = traffic_df2[(traffic_df2["Date Occurred"] == '2017-12-24')]['DR Number'].count()
ced18 = traffic_df2[(traffic_df2["Date Occurred"] == '2018-12-24')]['DR Number'].count()
ced19 = traffic_df2[(traffic_df2["Date Occurred"] == '2019-12-24')]['DR Number'].count()
ced = [ced15,ced16,ced17,ced18,ced19]

##CHRISTMAS DAY
xmd15 = traffic_df2[(traffic_df2["Date Occurred"] == '2015-12-25')]['DR Number'].count()
xmd16 = traffic_df2[(traffic_df2["Date Occurred"] == '2016-12-25')]['DR Number'].count()
xmd17 = traffic_df2[(traffic_df2["Date Occurred"] == '2017-12-25')]['DR Number'].count()
xmd18 = traffic_df2[(traffic_df2["Date Occurred"] == '2018-12-25')]['DR Number'].count()
xmd19 = traffic_df2[(traffic_df2["Date Occurred"] == '2019-12-25')]['DR Number'].count()
xmd = [xmd15,xmd16,xmd17,xmd18,xmd19]

##DAY AFTER CHRISTMAS
dxd15 = traffic_df2[(traffic_df2["Date Occurred"] == '2015-12-26')]['DR Number'].count()
dxd16 = traffic_df2[(traffic_df2["Date Occurred"] == '2016-12-26')]['DR Number'].count()
dxd17 = traffic_df2[(traffic_df2["Date Occurred"] == '2017-12-26')]['DR Number'].count()
dxd18 = traffic_df2[(traffic_df2["Date Occurred"] == '2018-12-26')]['DR Number'].count()
dxd19 = traffic_df2[(traffic_df2["Date Occurred"] == '2019-12-26')]['DR Number'].count()
dxd = [dxd15,dxd16,dxd17,dxd18,dxd19]

# %%
holidays15 = [nyd15,mlk15,pzd15,spd15,cdm15,mrd15,ind15,lbd15,cld15,vtd15,btd15,tgd15,atd15,ced15,xmd15,dxd15]
holidays16 = [nyd16,mlk16,pzd16,spd16,cdm16,mrd16,ind16,lbd16,cld16,vtd16,btd16,tgd16,atd16,ced16,xmd16,dxd16]
holidays17 = [nyd17,mlk17,pzd17,spd17,cdm17,mrd17,ind17,lbd17,cld17,vtd17,btd17,tgd17,atd17,ced17,xmd17,dxd17]
holidays18 = [nyd18,mlk18,pzd18,spd18,cdm18,mrd18,ind18,lbd18,cld18,vtd18,btd18,tgd18,atd18,ced18,xmd18,dxd18]
holidays19 = [nyd19,mlk19,pzd19,spd19,cdm19,mrd19,ind19,lbd19,cld19,vtd19,btd19,tgd19,atd19,ced19,xmd19,dxd19]

# %%
holidays = ['New Years', 'Martin Luther King Jr.', 'Presidents','St. Patricks','Cinco De Mayo', 
            'Memorial','Independence', 'Labor','Columbus','Veterans','Day Before Thanksgiving','Thanksgiving',
            'Thanksgiving (Day After)', 'Christmas Eve','Christmas Day','Christmas (Day After)']
time_df = pd.DataFrame({
                        '2015': holidays15,
                        '2016': holidays16,
                        '2017': holidays17,
                        '2018': holidays18,
                        '2019': holidays19,},index=holidays)
time_df
# Out:
#                           2015  2016  2017  2018  2019
# New Years                    6     8     3     6     3
# Martin Luther King Jr.       3     5     6     8     9
# Presidents                   6     2     5     3     7
# St. Patricks                 7     6     8    11    10
# Cinco De Mayo               11     7    12    11     5
# Memorial                     3     4     9     6     6
# Independence                 4     3     5     5     5
# Labor                        6     7     7     5     6
# Columbus                     6     9     3     6     7
# Veterans                    12    12     8     7     7
# Day Before Thanksgiving      5     3     9     7     5
# Thanksgiving                 3     8     6     6     4
# Thanksgiving (Day After)     6     6     6     7     5
# Christmas Eve               10     9     4     3     1
# Christmas Day                1     7     2     4     4
# Christmas (Day After)        8    10     7     7     3

# %%
holiday_frame = {'2015': holidays15,'2016': holidays16,'2017': holidays17,'2018': holidays18,'2019': holidays19,}
holiday_ct_df = pd.DataFrame(holiday_frame,index=holidays)
holiday_ct_df.plot.barh(stacked=True)
plt.tight_layout()
plt.savefig('../images/holidays.png')
# Out:
# <img src="data:image/png;base64,..." width="640">
